# %% [markdown]
# # Linear Regression Python Implementation

# %% [markdown]
# Generating Data

# %%
from sklearn.datasets._samples_generator import make_regression
from sklearn.model_selection import train_test_split
X, y = make_regression(n_samples=250, n_features=1, n_informative=1, noise=18, bias=30, random_state=200)
m = 200
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# %% [markdown]
# Visualizing Data

# %%
from matplotlib import pyplot as plt
plt.scatter(X,y, c = "red", alpha=.5, marker = 'o')
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# ## Linear Model

# %%
from linear_regression import LinearRegressor, r2_score
model = LinearRegressor(LR_rate=0.01, n_iters=1000)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
import numpy as np
accuracy = r2_score(y_test, y_pred)
mse = np.mean((y_test - y_pred)**2)

print(f"Mean Squared Error: {mse:.2f}")
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Mean Squared Error: 321.90
# Accuracy: 0.79

# %% [markdown]
# Vizualizing the Result

# %%
w = np.append(model.bias, model.weights)

def my_formula(x):
    return w[0] + w[1] * x

def graph(formula, x_range):
    x = np.array(x_range)
    y = formula(x)
    plt.plot(x, y)

plt.scatter(X, y, color="red", alpha=0.5, marker='o')
graph(my_formula, range(int(min(X)), int(max(X))+1))
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Regression Line')
plt.show()
# Out:
# C:\Users\aditya paliwal\AppData\Local\Temp\ipykernel_15280\1916243973.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   graph(my_formula, range(int(min(X)), int(max(X))+1))
